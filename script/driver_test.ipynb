# %%
import sys
sys.path.insert(0,'..')
import urx
ur = urx.Robot("192.168.1.10", use_rt=True)
pose = ur.get_pose()
print(pose)

# %%
import sys
sys.path.append('../ddh_driver')
from ddh_driver import Gripper
gripper = Gripper('default')
# Out:
# Load configuration at /home/john/high_speed_scooping/ddh_driver/config/default.yaml
# Connecting to Odrive(s)...
# Found Odrive_L
# Found Odrive_R

# %%
gripper.arm(finger = 'L')

# %%
gripper.arm(finger = 'R')

# %%
gripper.disarm()

# %%
gripper.set_stiffness(0,'L')

# %%
gripper.L0.stiffness

# %%
gripper.set_vel_gain(0,'L')

# %%
import math
while True:
#     print(gripper.link_to_tip(gripper.L0.theta,gripper.L1.theta,'L'))
#     print(gripper.link_to_tip(gripper.R0.theta,gripper.R1.theta,'R'))
#     print(gripper.right_tip_pos)
    print(gripper.left_phi)
# Out:
# -6.40414243425181
# -6.465890899045348
# -6.471439219326385
# -6.435456552740817
# -6.427654063473
# -6.466193218171668
# -6.410403270661902
# -6.451899711054438
# -6.444780403069274
# -6.431402175843743
# -6.4272477526912155
# -6.429642291427143
# -6.48282693265628
# -6.447563814483857
# -6.434604700098959
# -6.453524016834393
# -6.4670948506797
# -6.450437264972095
# -6.467275304667169
# -6.416832003555925
# -6.421227296859513
# -6.444755107333123
# -6.442459018642694
# -6.42374941411353
# -6.4475231024971436
# -6.419347640858319
# -6.4049854836026725
# -6.425552412344416
# -6.394596261861182
# -6.476981004815116
# -6.437438761959328
# -6.4555991044327925
# -6.422498664333347
# -6.450256397190486
# -6.3749890905459665
# -6.410113643280795
# -6.413993787773109
# -6.395563451301939
# -6.3752879029495375
# -6.419366390678704
# -6.465062946679922
# -6.42120356560514
# -6.462697808827244
# -6.445259016468242
# -6.431152304553791
# -6.399616335703286
# -6.471809906020326
# ...

# %% [markdown]
# # Auto scroll down

# %%
# %%javascript
#
# window.scroll_flag = true
# window.scroll_exit = false
# window.scroll_delay = 100
#
# $(".output_scroll").each(function() {
#     $(this)[0].scrollTop = $(this)[0].scrollHeight;
# });
#
# function callScrollToBottom() {
#     setTimeout(scrollToBottom, window.scroll_delay);
# }
#
# function scrollToBottom() {
#     if (window.scroll_exit) {
#         return;
#     }
#     if (!window.scroll_flag) {
#         callScrollToBottom();
#         return;
#     };
#
#     $(".output_scroll").each(function() {
#         if (!$(this).attr('scroll_checkbox')){
#             window.scroll_flag = true;
#             $(this).attr('scroll_checkbox',true);
#             var div = document.createElement('div');
#             var checkbox = document.createElement('input');
#             checkbox.type = "checkbox";
#             checkbox.onclick = function(){window.scroll_flag = checkbox.checked}
#             checkbox.checked = "checked"
#             div.append("Auto-Scroll-To-Bottom: ");
#             div.append(checkbox);
#             $(this).parent().before(div);
#         }
#
#         $(this)[0].scrollTop = $(this)[0].scrollHeight;
#     });
#     callScrollToBottom();
# }
# scrollToBottom();

# %%
streamer.enabled = True

# %%
streamer.enabled = False

# %%
print(streamer.info_actuators)
